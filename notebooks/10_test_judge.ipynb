# %% [markdown]
# # 10_test_judgeTest Judge decision-making.Tests:1. Run Judge with all inputs2. Verify Judge follows rules correctly3. Show cases for each rule

# %%
# Setup
import sys
from pathlib import Path

# Resolve project root
CWD = Path.cwd()
if (CWD / "configs").exists() and (CWD / "src").exists():
    PROJECT_ROOT = CWD
elif CWD.name == "notebooks" and (CWD.parent / "configs").exists():
    PROJECT_ROOT = CWD.parent
else:
    cur = CWD
    PROJECT_ROOT = CWD
    while cur != cur.parent:
        if (cur / "configs").exists() and (cur / "src").exists():
            PROJECT_ROOT = cur
            break
        cur = cur.parent

sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
print("\nNotebook:", title)
print("TODO: Add test cells based on roadmap requirements")
