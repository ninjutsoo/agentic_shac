# %% [markdown]
# # 11_test_full_pipelineTest end-to-end agentic pipeline on samples.Tests:1. Run full pipeline: Proposer → Refuter → Judge2. Compare: Baseline vs Agentic vs Gold3. Identify cases where agentic improves over baseline

# %%
# Setup
import sys
from pathlib import Path

# Resolve project root
CWD = Path.cwd()
if (CWD / "configs").exists() and (CWD / "src").exists():
    PROJECT_ROOT = CWD
elif CWD.name == "notebooks" and (CWD.parent / "configs").exists():
    PROJECT_ROOT = CWD.parent
else:
    cur = CWD
    PROJECT_ROOT = CWD
    while cur != cur.parent:
        if (cur / "configs").exists() and (cur / "src").exists():
            PROJECT_ROOT = cur
            break
        cur = cur.parent

sys.path.insert(0, str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
print("\nNotebook:", title)
print("TODO: Add test cells based on roadmap requirements")
